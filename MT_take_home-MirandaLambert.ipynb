# %% [markdown]
# <img src="https://images.efollett.com/htmlroot/images/templates/storeLogos/CA/864.gif" style="float: right;">
#
#
#
#
# # ECON628-01
# ### Midterm - Take Home
#
#
#
# ---
# #### Guidelines
# - This is your notebook for your take home midterm.
# - This part of your midterm, as you might expect, is **more challenging** so I highly recommend you to work ASAP.
#
# - You are required to submit your answers using this notebook (do not push or submit PDFs, Word docs, etc, cause your answers will be considered invalid = **0%**).
# - The take home is **15%** of your total midterm score.
# - You can work in groups of no more than **3** students.
# - Your code **should not be the same** as the rest of your classmates we will check (trust me on this!!), if your code is the same as any of your classmate **your grade will be penalized.**
# - The take home is due on **March 20** before class/exam (if you are taking the in-class exam before the rest of the class, you **need** to push your take home part before you commence with the in-class exam) = **NO EXCUSES !!**
# - Use this [link][1] to **submit/include** the GitHub link to your take home exam.
# [1]: https://docs.google.com/forms/d/e/1FAIpQLSfLkZJY80tw303ss8Ga_2sUMVgumAppWb4tYwssGTbr879_Mw/viewform "link"
# - If you find a piece of code online (from someone else), and you decide to use in your midterm, you need:
#     - Cite the website from where you are getting the code.
#     - **Explain on your "own words" what the code is doing.**
#     - If you fail to do this, your grade will be **penalized.**
# - Finally, you don't need to include models
# ---
#
# #### The data
#
# The state of Iowa provides many data sets on their website, we will be using a dataset which contains transactions for all stores that have a class E liquor license.
#
# The data , data dictionary can be found [directly on their website](https://data.iowa.gov/Economy/Iowa-Liquor-Sales/m3tr-qhgy).
#
# **However,** since many of you may have had computer issues reading medium size datasets, **everyone** needs to use the 10% dataset version of Iowa liquor sales, located in your dataset folder.
#
# ---
#
# #### Package imports

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')

# %% [markdown]
# ## 1. Load the data from file
#
# ---

# %%
iowa=pd.read_csv('C:\\Users\\Miranda\\Desktop\\ECON628-01-milambert\\datasets\\iowa_liquor\\Iowa_Liquor_sales_sample_10pct.csv')

# %% [markdown]
# ## 2. Do an initial overview of the data
#
# ---
#
# At the very least describe the columns/variables and the datatypes.

# %%
iowa
# Out:
#               Date  Store Number             City Zip Code  County Number  \
# 0       11/04/2015          3717           SUMNER    50674            9.0
# 1       03/02/2016          2614        DAVENPORT    52807           82.0
# 2       02/11/2016          2106      CEDAR FALLS    50613            7.0
# 3       02/03/2016          2501             AMES    50010           85.0
# 4       08/18/2015          3654          BELMOND    50421           99.0
# 5       04/20/2015          2569     CEDAR RAPIDS    52402           57.0
# 6       08/05/2015          2596          OTTUMWA    52501           90.0
# 7       06/25/2015          3456       CLEAR LAKE    50428           17.0
# 8       01/04/2016          4757        BONDURANT    50035           77.0
# 9       11/10/2015          4346       SHELLSBURG    52332            6.0
# 10      09/28/2015          2648  WEST DES MOINES    50265           77.0
# 11      10/28/2015          2600        OSKALOOSA    52577           62.0
# 12      01/22/2015          3858        DAVENPORT    52806           82.0
# 13      02/29/2016          4673       WEST POINT    52656           56.0
# 14      01/04/2016          2670       CORALVILLE    52241           52.0
# 15      06/10/2015          3717           SUMNER    50674            9.0
# 16      02/25/2016          2130         WATERLOO    50703            7.0
# 17      12/29/2015          2600        OSKALOOSA    52577           62.0
# 18      12/26/2015          4604           NEWTON    50208           50.0
# 19      03/04/2015          2614        DAVENPORT    52807           82.0
# 20      01/16/2015          2590     CEDAR RAPIDS    52402           57.0
# 21      01/13/2015          3942           TOLEDO    52342           86.0
# 22      03/24/2015          3981     SIOUX CENTER    51250           84.0
# 23      11/12/2015          4376       MASON CITY    50401           17.0
# 24      03/14/2016          2618     CEDAR RAPIDS    52402           57.0
# 25      02/03/2015          3390          MILFORD    51351           30.0
# 26      11/23/2015          3565        IOWA CITY    52246           52.0
# 27      04/21/2015          3963   COUNCIL BLUFFS    51501           78.0
# 28      12/01/2015          4375           GRIMES    50111           77.0
# 29      01/14/2015          2545        IOWA CITY    52245           52.0
# ...            ...           ...              ...      ...            ...
# 270925  01/05/2015          2837         WATERLOO    50702            7.0
# 270926  12/26/2015          2478          ALTOONA    50009           77.0
# 270927  08/31/2015          2633       DES MOINES    50320           77.0
# 270928  10/07/2015          3896        IOWA CITY    52240           52.0
# 270929  01/25/2016          5070           WILTON    52778           70.0
# 270930  10/13/2015          4634     CEDAR RAPIDS    52402           57.0
# 270931  05/26/2015          2602     WEBSTER CITY    50595           40.0
# 270932  06/18/2015          4604           NEWTON    50208           50.0
# 270933  02/26/2015          4987             AMES    50010           85.0
# 270934  03/18/2015          2623       SIOUX CITY    51104           97.0
# 270935  06/08/2015          5126       DES MOINES    50310           77.0
# 270936  03/31/2015          2552     CEDAR RAPIDS    52404           57.0
# 270937  01/27/2015          2553          CRESTON    50801           88.0
# 270938  04/29/2015          3890     CEDAR RAPIDS    52405           57.0
# 270939  05/04/2015          4876         HIAWATHA    52233           57.0
# 270940  01/21/2015          2523      CENTERVILLE    52544            4.0
# 270941  02/09/2015          4856           LISBON    52253           57.0
# 270942  06/15/2015          2512        IOWA CITY    52240           52.0
# 270943  10/21/2015          4438             AMES    50010           85.0
# 270944  03/22/2016          2620  WINDSOR HEIGHTS    50311           77.0
# 270945  06/11/2015          2627       DES MOINES    50310           77.0
# 270946  11/24/2015          5162        URBANDALE    50322           77.0
# 270947  05/12/2015          4375           GRIMES    50111           77.0
# 270948  04/08/2015          2545        IOWA CITY    52245           52.0
# 270949  07/21/2015          2529     CEDAR RAPIDS    52405           57.0
# 270950  12/22/2015          4057       DES MOINES    50316           77.0
# 270951  11/04/2015          5151        IDA GROVE    51445           47.0
# 270952  10/20/2015          5152         WATERLOO    50702            7.0
# 270953  11/20/2015          3562  WEST BURLINGTON    52655           29.0
# 270954  01/27/2015          4446        URBANDALE    50322           77.0
#
#                County   Category                       Category Name  \
# 0              Bremer  1051100.0                    APRICOT BRANDIES
# 1               Scott  1011100.0                    BLENDED WHISKIES
# 2          Black Hawk  1011200.0           STRAIGHT BOURBON WHISKIES
# 3               Story  1071100.0                  AMERICAN COCKTAILS
# 4              Wright  1031080.0                      VODKA 80 PROOF
# 5                Linn  1041100.0                   AMERICAN DRY GINS
# 6             Wapello  1051010.0             AMERICAN GRAPE BRANDIES
# 7         Cerro Gordo  1012100.0                   CANADIAN WHISKIES
# 8                Polk  1032080.0                      IMPORTED VODKA
# 9              Benton  1081315.0                   CINNAMON SCHNAPPS
# 10               Polk  1011250.0      SINGLE BARREL BOURBON WHISKIES
# 11            Mahaska  1071100.0                  AMERICAN COCKTAILS
# 12              Scott  1012100.0                   CANADIAN WHISKIES
# 13                Lee  1081300.0                 PEPPERMINT SCHNAPPS
# 14            Johnson  1031200.0                      VODKA FLAVORED
# 15             Bremer  1051100.0                    APRICOT BRANDIES
# 16         Black Hawk  1031100.0                     100 PROOF VODKA
# 17            Mahaska  1031200.0                      VODKA FLAVORED
# 18             Jasper  1081700.0         DISTILLED SPIRITS SPECIALTY
# 19              Scott  1012100.0                   CANADIAN WHISKIES
# 20               Linn  1031200.0                      VODKA FLAVORED
# 21               Tama  1012100.0                   CANADIAN WHISKIES
# 22              Sioux  1011100.0                    BLENDED WHISKIES
# 23        Cerro Gordo  1022100.0                             TEQUILA
# 24               Linn  1031080.0                      VODKA 80 PROOF
# 25          Dickinson  1011300.0                  TENNESSEE WHISKIES
# 26            Johnson  1012100.0                   CANADIAN WHISKIES
# 27      Pottawattamie  1011100.0                    BLENDED WHISKIES
# 28               Polk  1031080.0                      VODKA 80 PROOF
# 29            Johnson  1081600.0                     WHISKEY LIQUEUR
# ...               ...        ...                                 ...
# 270925     Black Hawk  1081200.0                      CREAM LIQUEURS
# 270926           Polk  1022100.0                             TEQUILA
# 270927           Polk  1031200.0                      VODKA FLAVORED
# 270928        Johnson  1031080.0                      VODKA 80 PROOF
# 270929      Muscatine  1031080.0                      VODKA 80 PROOF
# 270930           Linn  1031080.0                      VODKA 80 PROOF
# 270931       Hamilton  1081900.0  MISC. AMERICAN CORDIALS & LIQUEURS
# 270932         Jasper  1011300.0                  TENNESSEE WHISKIES
# 270933          Story  1062310.0                          SPICED RUM
# 270934       Woodbury  1051110.0                 BLACKBERRY BRANDIES
# 270935           Polk  1011300.0                  TENNESSEE WHISKIES
# 270936           Linn  1022100.0                             TEQUILA
# 270937          Union  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270938           Linn  1031080.0                      VODKA 80 PROOF
# 270939           Linn  1031200.0                      VODKA FLAVORED
# 270940      Appanoose  1012200.0                     SCOTCH WHISKIES
# 270941           Linn  1031080.0                      VODKA 80 PROOF
# 270942        Johnson  1011100.0                    BLENDED WHISKIES
# 270943          Story  1011200.0           STRAIGHT BOURBON WHISKIES
# 270944           Polk  1081240.0               GREEN CREME DE MENTHE
# 270945           Polk  1062200.0    PUERTO RICO & VIRGIN ISLANDS RUM
# 270946           Polk  1031080.0                      VODKA 80 PROOF
# 270947           Polk  1062310.0                          SPICED RUM
# 270948        Johnson  1062300.0                        FLAVORED RUM
# 270949           Linn  1031100.0                     100 PROOF VODKA
# 270950           Polk  1022100.0                             TEQUILA
# 270951            Ida  1011200.0           STRAIGHT BOURBON WHISKIES
# 270952     Black Hawk  1011300.0                  TENNESSEE WHISKIES
# 270953     Des Moines  1082900.0  MISC. IMPORTED CORDIALS & LIQUEURS
# 270954           Polk  1031080.0                      VODKA 80 PROOF
#
#         Vendor Number  Item Number                       Item Description  \
# 0                  55        54436              Mr. Boston Apricot Brandy
# 1                 395        27605                                Tin Cup
# 2                  65        19067                               Jim Beam
# 3                 395        59154                1800 Ultimate Margarita
# 4                 297        35918                     Five O'clock Vodka
# 5                 205        31473                      New Amsterdam Gin
# 6                  85        52806                          Korbel Brandy
# 7                  65        10628                   Canadian Club Whisky
# 8                 370        34006           Absolut Swedish Vodka 80 Prf
# 9                  65        82610                     Dekuyper Hot Damn!
# 10                 65        19235       Knob Creek Single Barrel Reserve
# 11                 55        57148          Chi-Chi's Margarita W/tequila
# 12                 65        15248                   Windsor Canadian Pet
# 13                322        75211                          Kinky Liqueur
# 14                380        41705                  Uv Red (cherry) Vodka
# 15                 55        54436              Mr. Boston Apricot Brandy
# 16                297        35913                     Five O'clock Vodka
# 17                380        41989                          Uv Cake Vodka
# 18                434        75087                        Juarez Gold Dss
# 19                434        13638           Lord Calvert Canadian Whisky
# 20                971        41474                   44 North Huckleberry
# 21                115        11786                  Black Velvet Traveler
# 22                260        25606            Seagrams 7 Crown Bl Whiskey
# 23                395        89196  Jose Cuervo Especial Reposado Tequila
# 24                297        35926                 Five O'clock PET Vodka
# 25                 85        26827          Jack Daniels Old #7 Black Lbl
# 26                260        11290       Crown Royal Canadian Whisky Mini
# 27                434        24156                  Hawkeye Blend Whiskey
# 28                380        37338                           UV Vodka PET
# 29                260        66199                 Piehole Apple Pie Mini
# ...               ...          ...                                    ...
# 270925            260        68306             Emmets Irish Cream Liqueur
# 270926            410        89646                           Patron Anejo
# 270927            260        77699                        Smirnoff Orange
# 270928            300        36904                    Mccormick Vodka Pet
# 270929            380        37346                         Phillips Vodka
# 270930            297        35914                     Five O'clock Vodka
# 270931             65        85526        Dekuyper Signature Blue Curacao
# 270932             85        26828          Jack Daniels Old #7 Black Lbl
# 270933            260        43336         Captain Morgan Original Spiced
# 270934             55        55068           Mr. Boston Blackberry Brandy
# 270935             85        86670          Jack Daniel's Tennessee Honey
# 270936            395        89196  Jose Cuervo Especial Reposado Tequila
# 270937             85        64676      Chambord Liqueur Royale De France
# 270938            260        37994                  Smirnoff Vodka 80 Prf
# 270939            380        42002                          Uv Cake Vodka
# 270940            305         4936                   Famous Grouse Scotch
# 270941             55        35948       Fleischmann's Royal Vodka 80 Prf
# 270942             65        24466         Kessler Blend Whiskey Traveler
# 270943             65        19061                          Jim Beam Mini
# 270944            434        79336        Paramount Creme De Menthe/green
# 270945             55        44215                       Barton Light Rum
# 270946            301        38176                            Titos Vodka
# 270947            260        43334              Captain Morgan Spiced Rum
# 270948             35        43145               Bacardi Pineapple Fusion
# 270949            300        36887                        McCormick Vodka
# 270950            410        88291             Patron Tequila Silver Mini
# 270951            259        17956              Evan Williams Str Bourbon
# 270952             85        26826          Jack Daniels Old #7 Black Lbl
# 270953            192        65258                   Jagermeister Liqueur
# 270954            260        37993                  Smirnoff Vodka 80 Prf
#
#         Bottle Volume (ml) State Bottle Cost State Bottle Retail  \
# 0                      750             $4.50               $6.75
# 1                      750            $13.75              $20.63
# 2                     1000            $12.59              $18.89
# 3                     1750             $9.50              $14.25
# 4                     1750             $7.20              $10.80
# 5                     1750            $13.32              $19.98
# 6                      750             $6.66               $9.99
# 7                     1750            $15.75              $23.63
# 8                      750            $11.49              $17.24
# 9                     1000             $7.62              $11.43
# 10                     750            $26.24              $39.36
# 11                    1750             $6.00               $9.25
# 12                    1750             $8.92              $13.38
# 13                     750            $10.00              $15.00
# 14                    1000             $7.50              $11.25
# 15                     750             $4.50               $6.75
# 16                     200             $1.13               $1.70
# 17                     750             $6.50               $9.75
# 18                    1000             $4.92               $7.38
# 19                    1750             $9.97              $14.96
# 20                     750            $14.25              $21.38
# 21                     750             $5.23               $7.85
# 22                     750             $7.00              $10.50
# 23                     750            $10.49              $15.74
# 24                     750             $3.37               $5.06
# 25                    1000            $17.90              $26.85
# 26                     300             $7.35              $11.03
# 27                     750             $3.50               $5.25
# 28                    1750            $10.99              $16.49
# 29                     500             $4.90               $7.35
# ...                    ...               ...                 ...
# 270925                 750             $6.00               $9.00
# 270926                 750            $31.00              $46.50
# 270927                1000             $9.25              $13.88
# 270928                 375             $1.80               $2.70
# 270929                 750             $3.57               $5.36
# 270930                 375             $1.93               $2.90
# 270931                 750             $5.25               $7.88
# 270932                1750            $29.67              $44.51
# 270933                 750             $9.00              $13.50
# 270934                1750            $10.00              $15.00
# 270935                 750            $15.07              $22.61
# 270936                 750            $10.49              $15.74
# 270937                 750            $18.56              $27.84
# 270938                 375             $4.75               $7.13
# 270939                 500             $4.89               $7.34
# 270940                 750            $12.03              $18.05
# 270941                1750             $6.68              $10.27
# 270942                 750             $5.51               $8.27
# 270943                 500             $6.83              $10.25
# 270944                 750             $4.75               $7.13
# 270945                 100             $0.89               $1.34
# 270946                 750             $9.65              $14.48
# 270947                 375             $5.00               $7.50
# 270948                 750             $8.50              $12.75
# 270949                1000             $4.13               $6.20
# 270950                 300            $20.30              $30.45
# 270951                 750             $7.47              $11.21
# 270952                 750            $15.07              $22.61
# 270953                1750            $26.05              $39.08
# 270954                 200             $2.75               $4.13
#
#         Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0                 12         $81.00                  9.00
# 1                  2         $41.26                  1.50
# 2                 24        $453.36                 24.00
# 3                  6         $85.50                 10.50
# 4                 12        $129.60                 21.00
# 5                  6        $119.88                 10.50
# 6                  3         $29.97                  2.25
# 7                  2         $47.26                  3.50
# 8                  4         $68.96                  3.00
# 9                  2         $22.86                  2.00
# 10                 6        $236.16                  4.50
# 11                 6         $55.50                 10.50
# 12                 1         $13.38                  1.75
# 13                12        $180.00                  9.00
# 14                12        $135.00                 12.00
# 15                 4         $27.00                  3.00
# 16                48         $81.60                  9.60
# 17                12        $117.00                  9.00
# 18                24        $177.12                 24.00
# 19                 6         $89.76                 10.50
# 20                 2         $42.76                  1.50
# 21                12         $94.20                  9.00
# 22                12        $126.00                  9.00
# 23                12        $188.88                  9.00
# 24                12         $60.72                  9.00
# 25                24        $644.40                 24.00
# 26                 1         $11.03                  0.30
# 27                 3         $15.75                  2.25
# 28                 6         $98.94                 10.50
# 29                 1          $7.35                  0.50
# ...              ...            ...                   ...
# 270925             4         $36.00                  3.00
# 270926             6        $279.00                  4.50
# 270927            12        $166.56                 12.00
# 270928            48        $129.60                 18.00
# 270929             4         $21.44                  3.00
# 270930            12         $34.80                  4.50
# 270931            12         $94.56                  9.00
# 270932             2         $89.02                  3.50
# 270933             3         $40.50                  2.25
# 270934             2         $30.00                  3.50
# 270935             3         $67.83                  2.25
# 270936            12        $188.88                  9.00
# 270937             1         $27.84                  0.75
# 270938             3         $21.39                  1.12
# 270939             6         $44.04                  3.00
# 270940             4         $72.20                  3.00
# 270941             6         $61.62                 10.50
# 270942            12         $99.24                  9.00
# 270943             1         $10.25                  0.50
# 270944             2         $14.26                  1.50
# 270945            48         $64.32                  4.80
# 270946             4         $57.92                  3.00
# 270947             6         $45.00                  2.25
# 270948             3         $38.25                  2.25
# 270949             3         $18.60                  3.00
# 270950             4        $121.80                  1.20
# 270951             3         $33.63                  2.25
# 270952             6        $135.66                  4.50
# 270953             6        $234.48                 10.50
# 270954             8         $33.04                  1.60
#
#         Volume Sold (Gallons)
# 0                        2.38
# 1                        0.40
# 2                        6.34
# 3                        2.77
# 4                        5.55
# 5                        2.77
# 6                        0.59
# 7                        0.92
# 8                        0.79
# 9                        0.53
# 10                       1.19
# 11                       2.77
# 12                       0.46
# 13                       2.38
# 14                       3.17
# 15                       0.79
# 16                       2.54
# 17                       2.38
# 18                       6.34
# 19                       2.77
# 20                       0.40
# 21                       2.38
# 22                       2.38
# 23                       2.38
# 24                       2.38
# 25                       6.34
# 26                       0.08
# 27                       0.59
# 28                       2.77
# 29                       0.13
# ...                       ...
# 270925                   0.79
# 270926                   1.19
# 270927                   3.17
# 270928                   4.76
# 270929                   0.79
# 270930                   1.19
# 270931                   2.38
# 270932                   0.92
# 270933                   0.59
# 270934                   0.92
# 270935                   0.59
# 270936                   2.38
# 270937                   0.20
# 270938                   0.30
# 270939                   0.79
# 270940                   0.79
# 270941                   2.77
# 270942                   2.38
# 270943                   0.13
# 270944                   0.40
# 270945                   1.27
# 270946                   0.79
# 270947                   0.59
# 270948                   0.59
# 270949                   0.79
# 270950                   0.32
# 270951                   0.59
# 270952                   1.19
# 270953                   2.77
# 270954                   0.42
#
# [270955 rows x 18 columns]

# %%
##It looks like there may be an outlier in Bottles Sold since the average is 6 and the my is 2508
##The same goes for Bottle Volume, Volume Sold in Liters and Gallons

iowa.describe()
##It appears that critical variables with a '$' are dropped from analysis.
# Out:
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         Store Number  County Number      Category  Vendor Number  \
# count  270955.000000  269878.000000  2.708870e+05   270955.00000
# mean     3590.263701      57.231642  1.043888e+06      256.43443
# std       947.662050      27.341205  5.018211e+04      141.01489
# min      2106.000000       1.000000  1.011100e+06       10.00000
# 25%      2604.000000            NaN           NaN      115.00000
# 50%      3722.000000            NaN           NaN      260.00000
# 75%      4378.000000            NaN           NaN      380.00000
# max      9023.000000      99.000000  1.701100e+06      978.00000
#
#          Item Number  Bottle Volume (ml)   Bottles Sold  Volume Sold (Liters)  \
# count  270955.000000       270955.000000  270955.000000         270955.000000
# mean    45974.963300          924.830341       9.871285              8.981351
# std     52757.043086          493.088489      24.040912             28.913690
# min       168.000000           50.000000       1.000000              0.100000
# 25%     26827.000000          750.000000       2.000000              1.500000
# 50%     38176.000000          750.000000       6.000000              5.250000
# 75%     64573.000000         1000.000000      12.000000             10.500000
# max    995507.000000         6000.000000    2508.000000           2508.000000
#
#        Volume Sold (Gallons)
# count          270955.000000
# mean                2.372830
# std                 7.638182
# min                 0.030000
# 25%                 0.400000
# 50%                 1.390000
# 75%                 2.770000
# max               662.540000

# %%
iowa.head()
# Out:
#          Date  Store Number         City Zip Code  County Number      County  \
# 0  11/04/2015          3717       SUMNER    50674            9.0      Bremer
# 1  03/02/2016          2614    DAVENPORT    52807           82.0       Scott
# 2  02/11/2016          2106  CEDAR FALLS    50613            7.0  Black Hawk
# 3  02/03/2016          2501         AMES    50010           85.0       Story
# 4  08/18/2015          3654      BELMOND    50421           99.0      Wright
#
#     Category              Category Name  Vendor Number  Item Number  \
# 0  1051100.0           APRICOT BRANDIES             55        54436
# 1  1011100.0           BLENDED WHISKIES            395        27605
# 2  1011200.0  STRAIGHT BOURBON WHISKIES             65        19067
# 3  1071100.0         AMERICAN COCKTAILS            395        59154
# 4  1031080.0             VODKA 80 PROOF            297        35918
#
#             Item Description  Bottle Volume (ml) State Bottle Cost  \
# 0  Mr. Boston Apricot Brandy                 750             $4.50
# 1                    Tin Cup                 750            $13.75
# 2                   Jim Beam                1000            $12.59
# 3    1800 Ultimate Margarita                1750             $9.50
# 4         Five O'clock Vodka                1750             $7.20
#
#   State Bottle Retail  Bottles Sold Sale (Dollars)  Volume Sold (Liters)  \
# 0               $6.75            12         $81.00                   9.0
# 1              $20.63             2         $41.26                   1.5
# 2              $18.89            24        $453.36                  24.0
# 3              $14.25             6         $85.50                  10.5
# 4              $10.80            12        $129.60                  21.0
#
#    Volume Sold (Gallons)
# 0                   2.38
# 1                   0.40
# 2                   6.34
# 3                   2.77
# 4                   5.55

# %%
print iowa.shape[0]
# Out:
# 270955

# %%
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                     270955 non-null object
# Store Number             270955 non-null int64
# City                     270955 non-null object
# Zip Code                 270955 non-null object
# County Number            269878 non-null float64
# County                   269878 non-null object
# Category                 270887 non-null float64
# Category Name            270323 non-null object
# Vendor Number            270955 non-null int64
# Item Number              270955 non-null int64
# Item Description         270955 non-null object
# Bottle Volume (ml)       270955 non-null int64
# State Bottle Cost        270955 non-null object
# State Bottle Retail      270955 non-null object
# Bottles Sold             270955 non-null int64
# Sale (Dollars)           270955 non-null object
# Volume Sold (Liters)     270955 non-null float64
# Volume Sold (Gallons)    270955 non-null float64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 37.2+ MB

# %%
##show columns in list

iowa.columns.tolist()
# Out:
# ['Date',
#  'Store Number',
#  'City',
#  'Zip Code',
#  'County Number',
#  'County',
#  'Category',
#  'Category Name',
#  'Vendor Number',
#  'Item Number',
#  'Item Description',
#  'Bottle Volume (ml)',
#  'State Bottle Cost',
#  'State Bottle Retail',
#  'Bottles Sold',
#  'Sale (Dollars)',
#  'Volume Sold (Liters)',
#  'Volume Sold (Gallons)']

# %%
##renaming variables with 2 words

iowa.rename(columns={
        'County Number':'county_num',
        'Category Name':'category_name',
        'Store Number':'store',
        'Zip Code':'zip',
        'Vendor Number': 'vendor',
        'Item Number':'item',
        'Item Description': 'description', 
        "Bottle Volume (ml)": 'bottle_volume_ml', 
        'State Bottle Cost': 'state_cost', 
        'State Bottle Retail': 'state_retail',
        'Bottles Sold': 'bottles_sold', 
        'Sale (Dollars)': 'sales',
        'Volume Sold (Liters)': 'volume_liters',
        'Volume Sold (Gallons)':'volume_gallons',
        }, inplace=True)

# %% [markdown]
# ## 3. Clean the dataset
#
# ---
#
# ### 3.1 Identify columns that you will need to convert and clean. Where and how is the data corrupted?
#
# Don't worry about converting the date column to a pandas/numpy "datetime" datatype, unless you want to (not required for these problems and is a challenging thing to work with in its own right.)

# %%
##Identify missing values
##most missing variables are from identifying categories 
##missing name categories should not effect analysis as long as we are able to replace the entry's number equivalent with the mean.
print iowa.isnull().sum()

##We previously identified that the sales columnsneeded to be fixed in order to be described.
# Out:
# Date                   0
# store                  0
# City                   0
# zip                    0
# county_num          1077
# County              1077
# Category              68
# category_name        632
# vendor                 0
# item                   0
# description            0
# bottle_volume_ml       0
# state_cost             0
# state_retail           0
# bottles_sold           0
# sales                  0
# volume_liters          0
# volume_gallons         0
# dtype: int64

# %% [markdown]
# # 3.2 Clean the columns

# %%
##defining a function to replace missing values with mean
##Code adapted from http://localhost:8888/notebooks/Desktop/ECON628-01-milambert/Project_1-Miranda_Lambert.ipynb
##And http://localhost:8888/notebooks/Desktop/ECON628-01-milambert/lectures/feb_13_2017/1.3-full-analysis.ipynb
def missing(d):
    if d.isnull().sum() > 0:
        print "Replaced Values = ",  d.isnull().sum()
        d.fillna(np.median(d), inplace=True)
    elif d.isnull().sum() == 0:
        print "No missing values"

# %%
##replace values with missing variables in 3.1
missing(iowa.Date)
# Out:
# No missing values

# %%
missing(iowa.Category)
# Out:
# Replaced Values =  68
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\numpy\lib\function_base.py:3569: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)

# %%
missing(iowa.county_num)
# Out:
# Replaced Values =  1077

# %%
##you can see that county number and category now have a value for the quartiles because there are no missing values.

iowa.describe()
# Out:
#                store     county_num      Category        vendor  \
# count  270955.000000  269878.000000  2.708870e+05  270955.00000
# mean     3590.263701      57.231642  1.043888e+06     256.43443
# std       947.662050      27.341205  5.018211e+04     141.01489
# min      2106.000000       1.000000  1.011100e+06      10.00000
# 25%      2604.000000            NaN           NaN     115.00000
# 50%      3722.000000            NaN           NaN     260.00000
# 75%      4378.000000            NaN           NaN     380.00000
# max      9023.000000      99.000000  1.701100e+06     978.00000
#
#                 item  bottle_volume_ml   bottles_sold  volume_liters  \
# count  270955.000000     270955.000000  270955.000000  270955.000000
# mean    45974.963300        924.830341       9.871285       8.981351
# std     52757.043086        493.088489      24.040912      28.913690
# min       168.000000         50.000000       1.000000       0.100000
# 25%     26827.000000        750.000000       2.000000       1.500000
# 50%     38176.000000        750.000000       6.000000       5.250000
# 75%     64573.000000       1000.000000      12.000000      10.500000
# max    995507.000000       6000.000000    2508.000000    2508.000000
#
#        volume_gallons
# count   270955.000000
# mean         2.372830
# std          7.638182
# min          0.030000
# 25%          0.400000
# 50%          1.390000
# 75%          2.770000
# max        662.540000

# %%
##Remove $ from important sales data and change to float, so that they can be described. 
##code adapted from http://stackoverflow.com/questions/29758623/how-to-convert-objects-in-dataframe-to-floats
col=['sales', 'state_retail', 'state_cost']
for i in col:
        iowa[i] = iowa[i].str.replace('$','').astype(float)

# %%
##it worked!!

iowa[['sales','state_retail', 'state_cost']].describe()
# Out:
#                sales   state_retail     state_cost
# count  270955.000000  270955.000000  270955.000000
# mean      128.902375      14.675760       9.773281
# std       383.027369      10.570145       7.047119
# min         1.340000       1.340000       0.890000
# 25%        30.450000       8.270000       5.500000
# 50%        70.560000      12.270000       8.000000
# 75%       135.000000      17.880000      11.920000
# max     36392.400000     637.500000     425.000000

# %%
iowa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270955 entries, 0 to 270954
# Data columns (total 18 columns):
# Date                270955 non-null object
# store               270955 non-null int64
# City                270955 non-null object
# zip                 270955 non-null object
# county_num          269878 non-null float64
# County              269878 non-null object
# Category            270887 non-null float64
# category_name       270323 non-null object
# vendor              270955 non-null int64
# item                270955 non-null int64
# description         270955 non-null object
# bottle_volume_ml    270955 non-null int64
# state_cost          270955 non-null float64
# state_retail        270955 non-null float64
# bottles_sold        270955 non-null int64
# sales               270955 non-null float64
# volume_liters       270955 non-null float64
# volume_gallons      270955 non-null float64
# dtypes: float64(7), int64(5), object(6)
# memory usage: 37.2+ MB

# %% [markdown]
# ### 3.3 Perform more extensive cleaning of the dataset
#
# Cleaning of data can mean a lot more than just fixing strings and numbers in columns. There are often logical errors with data, useless or nonsensical categories, redundancy of information, outliers, and many more problems.
#
# This dataset has problems beyond just fixing the types of columns. Keep in mind that some types of "data cleaning" is subjective: it's not always a cut-and-dry conversion of type or removal of null values. Subjectivity when dealing with data is just a fact of life when dealing with data. This isn't a kind of programming where things are just right or wrong.

# %%
#visualizing possible outliers
##code adapted from: http://localhost:8888/notebooks/Desktop/ECON628-01-milambert/lectures/feb_13_2017/1.3-full-analysis.ipynb
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot(iowa.volume_gallons, orient='v',
            fliersize=8, linewidth=1.5, notch=True, 
            saturation=0.5, ax=ax)

ax.set_ylabel('Gallons\n', fontsize=16)
ax.set_title('Volume in Gallons\n', fontsize=20)
ax.set_ylim(0,)
plt.show()

##There is a build up of sales at really low levels causing there to be a lot of extreme outliers. 
##The low mean level makes sense because gallons are a large volume measurement and we would not expect huge sales volumes in gallons.

# %%
##Limiting the y-axis to get a better look at the dispersion at low levels
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot(iowa.volume_gallons, orient='v',
            fliersize=8, linewidth=1.5, notch=True, 
            saturation=0.5, ax=ax)

ax.set_ylabel('Gallons\n', fontsize=16)
ax.set_title('Volume in Gallons\n', fontsize=20)
ax.set_ylim(0,50)
ax.set_ylim(0,)
plt.show()

##You can see the mean is really low in terms. This could make interpretation in Gallons more difficult.
##Additionally there are hundreds of outliers in the data. This makes it difficult to decide what to keep or to keep all of it because it is relevant to know when a store is selling mass quantities.

# %%
##visualize Liters
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot(iowa.volume_liters, orient='v',
            fliersize=8, linewidth=1.5, notch=True, 
            saturation=0.5, ax=ax)

ax.set_ylabel('Liters\n', fontsize=16)
ax.set_title('Volume in Liters\n', fontsize=20)
ax.set_ylim(0,)
plt.show()

##This looks similar to gallons as expected. These variables are considered redundatnt and should not both be used in analysis.

# %%
##code adapted from: http://localhost:8888/notebooks/Desktop/ECON628-01-milambert/lectures/feb_13_2017/1.3-full-analysis.ipynb

def histogram_plotter(title, data):
    sns.set(rc={"figure.figsize": (6, 4)})
    sns.set_style('white')
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    
    dist.axvline(np.mean(data), lw=5, c='blue')
    average_roll = '{0:.2f}'.format(np.mean(data))
    title = 'Distribution of ' + title + '; average = '  + average_roll + '\n'
    dist.set_title(title, fontsize=16)
    dist = sns.distplot(data, hist_kws={'alpha':0.2}, kde_kws={'linewidth':5})
    
histogram_plotter('Gallons Sold',iowa.volume_gallons)
plt.show()

# %%
##create bottle volume in ounces so that we can demonstrate results in terms of the (inefficient and admittedly 
##ridiculous) imperial measurement system to allow for Americans' better understanding 

iowa.bottle_vol_oz= iowa.bottle_volume_ml*.033814

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.gca()

sns.boxplot(iowa.sales, orient='v',
            fliersize=8, linewidth=1.5, notch=True, 
            saturation=0.5, ax=ax)

ax.set_ylabel('Sales\n', fontsize=16)
ax.set_title('Sales in Dollars\n', fontsize=20)
plt.show()


##You can see that their are several outliers here as well, but there is a distinct separation right around $20000.
##I will filter out these extreme outliers, so that they do not skew the analysis.

# %%
##Creating the mask for Sales outliers

mask=iowa['sales'] < 20000
iowa= iowa[mask]
iowa.describe()
# Out:
#                store     county_num      Category         vendor  \
# count  270951.000000  269874.000000  2.708830e+05  270951.000000
# mean     3590.261571      57.231827  1.043888e+06     256.435721
# std       947.664766      27.341238  5.018239e+04     141.014879
# min      2106.000000       1.000000  1.011100e+06      10.000000
# 25%      2604.000000            NaN           NaN     115.000000
# 50%      3722.000000            NaN           NaN     260.000000
# 75%      4378.000000            NaN           NaN     380.000000
# max      9023.000000      99.000000  1.701100e+06     978.000000
#
#                 item  bottle_volume_ml     state_cost   state_retail  \
# count  270951.000000     270951.000000  270951.000000  270951.000000
# mean    45975.175032        924.827386       9.773116      14.675513
# std     52757.400430        493.089423       7.046960      10.569907
# min       168.000000         50.000000       0.890000       1.340000
# 25%     26827.000000        750.000000       5.500000       8.270000
# 50%     38176.000000        750.000000       8.000000      12.270000
# 75%     64573.000000       1000.000000      11.920000      17.880000
# max    995507.000000       6000.000000     425.000000     637.500000
#
#         bottles_sold          sales  volume_liters  volume_gallons
# count  270951.000000  270951.000000  270951.000000   270951.000000
# mean        9.854335     128.446783       8.963746        2.368180
# std        23.566823     363.921560      28.505877        7.530449
# min         1.000000       1.340000       0.100000        0.030000
# 25%         2.000000      30.450000       1.500000        0.400000
# 50%         6.000000      70.560000       5.250000        1.390000
# 75%        12.000000     135.000000      10.500000        2.770000
# max      2508.000000   17916.000000    2508.000000      662.540000

# %%
##The mean drops slightly in both sales and volume categories.

# %% [markdown]
# ## 4. Filter/adjust the store data
#
# ---
#
# Some stores may have opened or closed in 2015. These stores will have incorrect yearly summary statistics since they were not open the full year. We need to filter them out or find another way to deal with the inconsistent numbers of months across stores.
#
# It is up to you how you want to deal with this problem.
#
# 1. Investigate problematic stores.
# 2. Decide on an approach to deal with stores not open for the full 2015 year.
# 3. Implement your plan.
# 4. Briefly report on what you did and why.

# %%
##fixing the date column and creating quarters

iowa['Date']=pd.to_datetime(iowa['Date'])
iowa ['year'], iowa['month']=iowa['Date'].dt.year, iowa['Date'].dt.month
iowa['quarter']=iowa ['Date'].dt.quarter
iowa.head()
# Out:
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         Date  store         City    zip  county_num      County   Category  \
# 0 2015-11-04   3717       SUMNER  50674         9.0      Bremer  1051100.0
# 1 2016-03-02   2614    DAVENPORT  52807        82.0       Scott  1011100.0
# 2 2016-02-11   2106  CEDAR FALLS  50613         7.0  Black Hawk  1011200.0
# 3 2016-02-03   2501         AMES  50010        85.0       Story  1071100.0
# 4 2015-08-18   3654      BELMOND  50421        99.0      Wright  1031080.0
#
#                category_name  vendor   item   ...    bottle_volume_ml  \
# 0           APRICOT BRANDIES      55  54436   ...                 750
# 1           BLENDED WHISKIES     395  27605   ...                 750
# 2  STRAIGHT BOURBON WHISKIES      65  19067   ...                1000
# 3         AMERICAN COCKTAILS     395  59154   ...                1750
# 4             VODKA 80 PROOF     297  35918   ...                1750
#
#    state_cost  state_retail  bottles_sold   sales  volume_liters  \
# 0        4.50          6.75            12   81.00            9.0
# 1       13.75         20.63             2   41.26            1.5
# 2       12.59         18.89            24  453.36           24.0
# 3        9.50         14.25             6   85.50           10.5
# 4        7.20         10.80            12  129.60           21.0
#
#    volume_gallons  year  month  quarter
# 0            2.38  2015     11        4
# 1            0.40  2016      3        1
# 2            6.34  2016      2        1
# 3            2.77  2016      2        1
# 4            5.55  2015      8        3
#
# [5 rows x 21 columns]

# %%
##This creates aggregate sales for each quarter by individual store locations

quarter_sales_group = iowa.groupby(['store','year', 'quarter'])['sales', 'state_retail', 'state_cost'].agg(np.sum).reset_index()
quarter_sales_group.rename(columns = {'sales': 'quarterly_sales'}, inplace=True)

quarter_sales_group.head(5)
# Out:
#    store  year  quarter  quarterly_sales  state_retail  state_cost
# 0   2106  2015        1         39287.29       1944.71     1295.36
# 1   2106  2015        2         31173.46       2095.20     1395.73
# 2   2106  2015        3         38324.77       2126.20     1416.60
# 3   2106  2015        4         37540.70       1989.67     1325.44
# 4   2106  2016        1         30523.75       1983.05     1320.79

# %%
##creating dataframes for each quarter and then separating quarters for of 2015

iowa_merge=iowa.merge(quarter_sales_group, on=['store', 'year', 'quarter'], how='left')
quarter1_sales=iowa[iowa['quarter']==1].groupby(['store', 'year'])['sales'].agg(np.sum).reset_index()
quarter1_sales=quarter1_sales.rename(columns={'sales': 'quarter1_sales'})
quarter1_sales.head()
# Out:
#    store  year  quarter1_sales
# 0   2106  2015        39287.29
# 1   2106  2016        30523.75
# 2   2113  2015         2833.25
# 3   2113  2016         2065.90
# 4   2130  2015        24272.57

# %%
quarter1_sales15=quarter1_sales[quarter1_sales['year']==2015].groupby(['store'])['quarter1_sales'].agg(np.sum).reset_index()
quarter1_sales15=quarter1_sales15.rename(columns={'quarter1_sales':'quarter1_sales15'})
quarter1_sales15.head()
# Out:
#    store  quarter1_sales15
# 0   2106          39287.29
# 1   2113           2833.25
# 2   2130          24272.57
# 3   2152           2003.46
# 4   2178           5856.41

# %%
##quarter 2
quarter2_sales=iowa[iowa['quarter']==2].groupby(['store', 'year'])['sales'].agg(np.sum).reset_index()
quarter2_sales=quarter2_sales.rename(columns={'sales':'quarter2_sales'})
quarter2_sales.head()
# Out:
#    store  year  quarter2_sales
# 0   2106  2015        31173.46
# 1   2113  2015         1994.30
# 2   2130  2015        35038.09
# 3   2152  2015         1398.92
# 4   2178  2015         6986.33

# %%
##quarter 2 of 2015
quarter2_sales15=quarter2_sales[quarter2_sales['year']==2015].groupby(['store'])['quarter2_sales'].agg(np.sum).reset_index()
quarter2_sales15=quarter2_sales15.rename(columns={'quarter2_sales':'quarter2_sales15'})
##quarters 1 and 2
quarter12_sales15=quarter1_sales15.merge(quarter2_sales15, on=['store'], how='left')
quarter12_sales15.head()
# Out:
#    store  quarter1_sales15  quarter2_sales15
# 0   2106          39287.29          31173.46
# 1   2113           2833.25           1994.30
# 2   2130          24272.57          35038.09
# 3   2152           2003.46           1398.92
# 4   2178           5856.41           6986.33

# %%
##quarter 3
quarter3_sales=iowa[iowa['quarter']==3].groupby(['store', 'year'])['sales'].agg(np.sum).reset_index()
quarter3_sales=quarter3_sales.rename(columns={'sales':'quarter3_sales'})
quarter3_sales15=quarter3_sales[quarter3_sales['year']==2015].groupby(['store'])['quarter3_sales'].agg(np.sum).reset_index()
quarter3_sales15=quarter3_sales15.rename(columns={'quarter3_sales':'quarter3_sales15'})
##combine quarters 1,2,and 3
quarter123_sales15=quarter12_sales15.merge(quarter3_sales15, on=['store'], how='left')
quarter123_sales15.head()
# Out:
#    store  quarter1_sales15  quarter2_sales15  quarter3_sales15
# 0   2106          39287.29          31173.46          38324.77
# 1   2113           2833.25           1994.30           2113.56
# 2   2130          24272.57          35038.09          24605.88
# 3   2152           2003.46           1398.92           2246.70
# 4   2178           5856.41           6986.33           5668.15

# %%
##quarter 4 
quarter4_sales=iowa[iowa['quarter']==4].groupby(['store', 'year'])['sales'].agg(np.sum).reset_index()
quarter4_sales=quarter4_sales.rename(columns={'sales':'quarter4_sales'})
quarter4_sales15=quarter4_sales[quarter4_sales['year']==2015].groupby(['store'])['quarter4_sales'].agg(np.sum).reset_index()
quarter4_sales15=quarter4_sales15.rename(columns={'quarter4_sales':'quarter4_sales15'})
##All 4 2015 quarters
quarterly_sales15=quarter123_sales15.merge(quarter4_sales15, on=['store'], how='left')
quarterly_sales15.head()
# Out:
#    store  quarter1_sales15  quarter2_sales15  quarter3_sales15  \
# 0   2106          39287.29          31173.46          38324.77
# 1   2113           2833.25           1994.30           2113.56
# 2   2130          24272.57          35038.09          24605.88
# 3   2152           2003.46           1398.92           2246.70
# 4   2178           5856.41           6986.33           5668.15
#
#    quarter4_sales15
# 0          37540.70
# 1           2369.11
# 2          27954.89
# 3           2072.00
# 4           5813.29

# %%
##First quarter of 2016
quarter1_sales16=quarter1_sales[quarter1_sales['year']==2016].groupby(['store'])['quarter1_sales'].agg(np.sum).reset_index()
quarter1_sales16=quarter1_sales16.rename(columns={'quarter1_sales':'quarter1_sales16'})
quarter1_sales16.head()
# Out:
#    store  quarter1_sales16
# 0   2106          30523.75
# 1   2113           2065.90
# 2   2130          27856.11
# 3   2152           1376.43
# 4   2178           5588.50

# %%
quarter_sales=quarterly_sales15.merge(quarter1_sales16, on=['store'], how='left')
quarter_sales.head()
# Out:
#    store  quarter1_sales15  quarter2_sales15  quarter3_sales15  \
# 0   2106          39287.29          31173.46          38324.77
# 1   2113           2833.25           1994.30           2113.56
# 2   2130          24272.57          35038.09          24605.88
# 3   2152           2003.46           1398.92           2246.70
# 4   2178           5856.41           6986.33           5668.15
#
#    quarter4_sales15  quarter1_sales16
# 0          37540.70          30523.75
# 1           2369.11           2065.90
# 2          27954.89          27856.11
# 3           2072.00           1376.43
# 4           5813.29           5588.50

# %%
quarter_sales['sales_2015']=quarter_sales['quarter1_sales15']+quarter_sales['quarter2_sales15']+quarter_sales['quarter3_sales15']+quarter_sales['quarter4_sales15']
quarter_sales.sales_2015.head()
# Out:
# 0    146326.22
# 1      9310.22
# 2    111871.43
# 3      7721.08
# 4     24324.18
# Name: sales_2015, dtype: float64

# %%
##replace missing values with 0 to see who was not open in the quarters

def missing(d):
    if d.isnull().sum()>0:
        print 'replaced=', d.isnull().sum()
        d.fillna(0, inplace=True)
    elif d.isnull().sum() == 0:
        print 'no missing'
        
missing(quarter_sales.quarter1_sales15)
missing(quarter_sales.quarter2_sales15)
missing(quarter_sales.quarter3_sales15)
missing(quarter_sales.quarter4_sales15)
missing(quarter_sales.quarter1_sales16)
# Out:
# no missing
# replaced= 37
# replaced= 57
# replaced= 73
# replaced= 79

# %%
##Clean the data of all stores that had a full quarter with no sales. This eludes to the fact that they either opened or closed within the year.

mask_q1=quarter_sales['quarter1_sales15']!=0
quarter1_sales_mask=quarter_sales[mask_q1].reset_index()

mask_q12=quarter1_sales_mask['quarter2_sales15']!=0
quarter12_sales_mask=quarter1_sales_mask[mask_q12].reset_index()

mask_q123=quarter12_sales_mask['quarter3_sales15']!=0
quarter123_sales_mask=quarter12_sales_mask[mask_q123]

mask_q1234=quarter123_sales_mask['quarter4_sales15']!=0
quarter1234_sales_mask=quarter123_sales_mask[mask_q1234]

mask_q12345=quarter1234_sales_mask['quarter1_sales16']!=0
quarter_sales=quarter1234_sales_mask[mask_q12345]
quarter_sales.describe()
# Out:
#            level_0        index        store  quarter1_sales15  \
# count  1170.000000  1170.000000  1170.000000       1170.000000
# mean    625.295726   625.295726  4154.544444       5083.214632
# std     362.581104   362.581104   801.647012      11977.314109
# min       0.000000     0.000000  2106.000000         11.210000
# 25%     313.250000   313.250000  3789.250000        892.392500
# 50%     626.500000   626.500000  4371.500000       1904.120000
# 75%     935.750000   935.750000  4732.750000       4725.580000
# max    1260.000000  1260.000000  9002.000000     207012.080000
#
#        quarter2_sales15  quarter3_sales15  quarter4_sales15  quarter1_sales16  \
# count       1170.000000       1170.000000       1170.000000       1170.000000
# mean        6012.085094       5549.277239       6769.675607       5194.993769
# std        14703.851284      12158.624350      15879.804133      12212.845149
# min           32.400000         82.260000         53.270000         30.600000
# 25%          965.582500       1008.585000       1035.787500        974.795000
# 50%         2070.110000       2099.940000       2316.485000       1908.280000
# 75%         5377.325000       5171.150000       6179.655000       4748.410000
# max       277634.390000     212606.590000     267137.840000     219551.790000
#
#           sales_2015
# count    1170.000000
# mean    23414.252573
# std     53828.656810
# min       450.010000
# 25%      3951.765000
# 50%      8573.455000
# 75%     22351.900000
# max    964390.900000

# %% [markdown]
# Report:

# %% [markdown]
# In order to deal with the fact that some stores opened/closed during 2015 (and knowing we need to use quarterly data for numberr 6), we first divide the data into quarters. The idea is that if the store has no sales for an entire quarter, they were not open in that quarter adn should therefore not be included in a 2015 analysis. The final "quarter_sales" data frame replaces the former quarter_sales frame without these values. With this, we can see the new sales totals for each quarter of the year and the new total sales for the year.

# %% [markdown]
# ## 5. Case 1 - Proposals for new tax rates
#
# ---
#
# You are an economist working for the Iowa State tax board. The Iowa State legislature is considering changes in the liquor tax rates and has assigned you to the project.
#
# ### 5.1 Calculate yearly liquor sales for each store in 2015.

# %%
##Generate a uniques store identifier 

store = []
for i in iowa.store:
    if i not in store:
        store.append(i)  
print len(store)
# Out:
# 1400

# %%
yearly_sales=iowa.groupby(['store', 'year'])['sales'].sum().reset_index()
yearly_sales.rename(columns= {'sales':'annual_sales'}, inplace=True)
##generate a mask to output only 2015 sales for each store
mask=yearly_sales['year'] == 2015
yearly_sales= yearly_sales[mask].reset_index()

yearly_sales.head()
# Out:
#    index  store  year  annual_sales
# 0      0   2106  2015     146326.22
# 1      2   2113  2015       9310.22
# 2      4   2130  2015     111871.43
# 3      6   2152  2015       7721.08
# 4      8   2178  2015      24324.18

# %%
yearly_sales.describe()
# Out:
#              index        store    year   annual_sales
# count  1372.000000  1372.000000  1372.0    1372.000000
# mean   1328.688776  4241.981778  2015.0   20725.561829
# std     767.913339   838.584463     0.0   50307.776406
# min       0.000000  2106.000000  2015.0      39.020000
# 25%     664.500000  3857.750000  2015.0    3206.002500
# 50%    1328.000000  4438.500000  2015.0    7231.055000
# 75%    1995.500000  4824.250000  2015.0   19355.705000
# max    2679.000000  9018.000000  2015.0  964390.900000

# %% [markdown]
# ### 5.2 Calculate the profit each store is making in 2015.

# %%
##profit=revenue (sales in this case)-cost
iowa['cost']= iowa['state_cost'] * iowa['bottles_sold']
iowa.cost.describe()
# Out:
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# count    270951.000000
# mean         85.501221
# std         241.685775
# min           0.890000
# 25%          20.280000
# 50%          46.800000
# 75%          90.000000
# max       11880.000000
# Name: cost, dtype: float64

# %%
iowa['profit']=iowa['sales']-iowa['cost']
iowa.profit.describe()
# Out:
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# count    270951.000000
# mean         42.945562
# std         122.276069
# min           0.000000
# 25%          10.160000
# 50%          23.520000
# 75%          45.000000
# max        6276.000000
# Name: profit, dtype: float64

# %%
yearly_profit=iowa.groupby(['store', 'year'])['profit'].sum().reset_index()
yearly_profit.rename(columns= {'profit':'annual_profit'}, inplace=True)
##generate a mask to output only 2015 sales for each store
mask=yearly_profit['year'] == 2015
yearly_profit= yearly_profit[mask].reset_index()
yearly_profit.head()
# Out:
#    index  store  year  annual_profit
# 0      0   2106  2015       48838.08
# 1      2   2113  2015        3109.04
# 2      4   2130  2015       37325.20
# 3      6   2152  2015        2587.53
# 4      8   2178  2015        8165.70

# %%
yearly_profit.describe()
# Out:
#              index        store    year  annual_profit
# count  1372.000000  1372.000000  1372.0    1372.000000
# mean   1328.688776  4241.981778  2015.0    6931.169577
# std     767.913339   838.584463     0.0   16799.370943
# min       0.000000  2106.000000  2015.0      13.340000
# 25%     664.500000  3857.750000  2015.0    1070.252500
# 50%    1328.000000  4438.500000  2015.0    2417.480000
# 75%    1995.500000  4824.250000  2015.0    6483.000000
# max    2679.000000  9018.000000  2015.0  321686.110000

# %%
##skewed by outliers with huge profits 

histogram_plotter('Annual Profit', yearly_profit.annual_profit)

# %% [markdown]
# ### 5.3 Investigate which Iowa counties are making the most profit on liquor per gallon in 2015.

# %%
iowa['profit_gallon']=iowa['profit']/iowa['volume_gallons']
iowa.profit_gallon.describe()
# Out:
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# count    270951.000000
# mean         22.773595
# std          16.691232
# min           0.000000
# 25%          12.238267
# 50%          18.846154
# 75%          28.750000
# max        1062.500000
# Name: profit_gallon, dtype: float64

# %%
yearly_profit_gallon=iowa.groupby(['store', 'year'])['profit_gallon'].mean().reset_index()
yearly_profit_gallon.rename(columns= {'profit':'annual_profitpergallon'}, inplace=True)
##generate a mask to output only 2015 profit per gallon for each store
mask=yearly_profit_gallon['year'] == 2015
yearly_profit_gallon= yearly_profit_gallon[mask].reset_index()
yearly_profit_gallon.head()
# Out:
#    index  store  year  profit_gallon
# 0      0   2106  2015      22.540937
# 1      2   2113  2015      23.352969
# 2      4   2130  2015      21.255557
# 3      6   2152  2015      16.466305
# 4      8   2178  2015      20.271232

# %%
profit_by_county=iowa.groupby(['county_num']) [['profit_gallon']].mean().reset_index()
profit_by_county=profit_by_county.sort_values(['profit_gallon'], ascending=[0])
profit_by_county
##you can see couty 77 is the most profitable per gallon. This is Polk county where Des Moines, Iowa (the state's largest city)is located.
#This makes sense because Des Moines likely has the highest Demand for Liquor.
# Out:
#     county_num  profit_gallon
# 76        77.0      24.791439
# 51        52.0      24.485938
# 81        82.0      24.161512
# 50        51.0      23.889861
# 6          7.0      23.597976
# 84        85.0      23.578144
# 10        11.0      23.562740
# 56        57.0      23.538735
# 96        97.0      23.336831
# 28        29.0      23.287958
# 91        92.0      23.261398
# 68        69.0      22.927093
# 55        56.0      22.846043
# 24        25.0      22.763283
# 43        44.0      22.581835
# 69        70.0      22.479876
# 74        75.0      22.476196
# 93        94.0      22.414620
# 30        31.0      22.373548
# 77        78.0      22.367405
# 61        62.0      22.336325
# 78        79.0      22.272728
# 29        30.0      22.192795
# 31        32.0      21.973388
# 89        90.0      21.952217
# 22        23.0      21.892177
# 16        17.0      21.880335
# 58        59.0      21.879166
# 60        61.0      21.834223
# 63        64.0      21.773035
# ..         ...            ...
# 90        91.0      19.907246
# 80        81.0      19.890907
# 65        66.0      19.848231
# 0          1.0      19.782364
# 41        42.0      19.752056
# 52        53.0      19.741197
# 15        16.0      19.692086
# 2          3.0      19.577486
# 94        95.0      19.574365
# 64        65.0      19.284108
# 98        99.0      19.177155
# 17        18.0      19.172217
# 32        33.0      19.049750
# 5          6.0      19.011035
# 92        93.0      18.874491
# 48        49.0      18.816224
# 47        48.0      18.784424
# 35        36.0      18.632791
# 18        19.0      18.562775
# 38        39.0      18.389939
# 37        38.0      18.357706
# 75        76.0      18.210787
# 97        98.0      18.171546
# 25        26.0      18.114578
# 53        54.0      18.088479
# 11        12.0      17.987237
# 4          5.0      17.948797
# 12        13.0      17.527584
# 79        80.0      16.300326
# 40        41.0      15.870200
#
# [99 rows x 2 columns]

# %%
sns.barplot (x='County', y='profit_gallon', data=iowa)


plt.xlabel("", fontsize=14)
plt.ylabel("Profit per Gallon", fontsize=14)
plt.title('Profit by county')

##This is not the best visualization, but it shows that there is not huge variations in profit throughout counties. 
##The last chart shows that the range is between 15-24

# %% [markdown]
# ### 5.4  Does profit scale proportionally to store size?
#
# Size of a store can be defined as the total gallons sold in 2015. Is the profit to store size ratio increasing as store size increases? Decreasing? Consistent?

# %%
store_size=iowa.groupby(['store', 'year'])['volume_gallons'].sum().reset_index()
store_size.rename(columns= {'volume_gallons':'store_size'}, inplace=True)
##generate a mask to output only 2015 store size for each store
mask=store_size['year'] == 2015
store_size= store_size[mask]
store_size.head()
# Out:
#    store  year  store_size
# 0   2106  2015     2571.33
# 2   2113  2015      174.29
# 4   2130  2015     1820.65
# 6   2152  2015      167.28
# 8   2178  2015      506.50

# %%
store_size.describe()
# Out:
#              store    year    store_size
# count  1372.000000  1372.0   1372.000000
# mean   4241.981778  2015.0    381.928907
# std     838.584463     0.0    846.324903
# min    2106.000000  2015.0      0.200000
# 25%    3857.750000  2015.0     61.320000
# 50%    4438.500000  2015.0    139.635000
# 75%    4824.250000  2015.0    365.095000
# max    9018.000000  2015.0  16007.310000

# %%
store_size['profit_2_size']=store_size['store_size']/iowa['profit']
size_profit=store_size.groupby(['store', 'year'])['profit_2_size'].sum().reset_index()

##generate a mask to output only 2015 profit to store size for each store
mask=size_profit['year'] == 2015
size_profit= size_profit[mask]
size_profit.head()
# Out:
#    store  year  profit_2_size
# 0   2106  2015      95.234444
# 1   2113  2015       1.152712
# 2   2130  2015      42.144676
# 3   2152  2015      16.744745
# 4   2178  2015      22.021739

# %%
ax=sns.regplot(x='store_size', y='profit_2_size', data=store_size)

# %% [markdown]
# ### 5.5 Create a broader category for liquor type.
#
# Liquor types are pretty granular in this dataset. Create a column that categorizes these types into a smaller amount of categories. The categories you decide on are up to you.

# %%
##drop if Category is blank

iowa.dropna(subset=['Category'], inplace=True)
# Out:
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
##Combine liquor into 8 categories: 0= Beer 1=Whiskey, 2=Tequila, 3=Vodka, 4=Gin, 5=Brandy, 6=Rum, 7=Cocktail, 8=Misc

iowa['broad_category']=iowa['Category'].astype(str).str[2]
iowa.broad_category.describe()
# Out:
# C:\Users\Miranda\AppData\Local\Continuum\Anaconda2\envs\econ\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# count     270883
# unique        10
# top            1
# freq       73444
# Name: broad_category, dtype: object

# %%
##Visualize
sns.barplot (x='broad_category', y='sales', data=iowa)


plt.xlabel("Liquor Types", fontsize=14)
plt.ylabel("Sales in Dollars", fontsize=14)
plt.title('Sales by Liquor Type\n', fontsize=16)
plt.show()

##A lot of Tequila and vodka being sold

# %%
sales_by_brand=iowa.groupby(['broad_category']) [['sales']].mean().reset_index()
sales_by_brand=sales_by_brand.sort_values(['sales'], ascending=[0])
sales_by_brand.head(10)
# Out:
#   broad_category       sales
# 0              0  222.112036
# 2              2  156.359974
# 9              9  155.528333
# 1              1  148.418565
# 6              6  139.477157
# 3              3  118.964317
# 8              8  117.288844
# 5              5   98.601316
# 4              4   92.524638
# 7              7   82.492849

# %% [markdown]
# ### 5.6 Do relationships exist between the broader liquor type and profit?

# %%
sales_by_brand=iowa.groupby(['broad_category']) [['profit']].mean().reset_index()
sales_by_brand=sales_by_brand.sort_values(['profit'], ascending=[0])
sales_by_brand.head(10)

##High Profits on tequila#profit by category

sns.barplot (x='broad_category', y='profit', data=iowa)


plt.xlabel("Liquor Types", fontsize=14)
plt.ylabel("Profit in Dollars", fontsize=14)
plt.title('Profit by Liquor Type\n', fontsize=16)
plt.show()

##High profits on tequila and liquor

# %% [markdown]
# ### 5.7 Are there any noticeable relationships between liquor brand and sales? Profit?

# %%
sns.barplot (x='description', y='sales', data=iowa)


plt.xlabel("Liquor Types", fontsize=14)
plt.ylabel("Sales in Dollars", fontsize=14)
plt.title('Sales by Brand\n', fontsize=16)
plt.show()

# %%
sns.barplot (x='description', y='profit', data=iowa)


plt.xlabel("Liquor Types", fontsize=14)
plt.ylabel("Profit in Dollars", fontsize=14)
plt.title('Profit by Brand\n', fontsize=16)
plt.show()

##It looks like a few types of liquor have higher sales and profit margins. We will have to look further into this to see which ones.

# %%
sales_by_brand=iowa.groupby(['description']) [['sales']].mean().reset_index()
sales_by_brand=sales_by_brand.sort_values(['sales'], ascending=[0])
sales_by_brand.head(10)
# Out:
#                                        description         sales
# 467   Cedar Ridge Single Malt Single Barrel Select  14602.500000
# 1335                           Member's Mark Vodka   4668.060000
# 1108                  Jim Beam Operation Homefront   4252.114286
# 1334                      Member's Mark Spiced Rum   3913.920000
# 1333                                   Medea Vodka   3221.640000
# 69                           Absolut w/Ginger Beer   2399.200000
# 1272                            Macallan FO 17year   2163.960000
# 603                             Crystal Malt 200ml   1721.160000
# 1264                            Luxardo Maraschino   1260.000000
# 1457                       Paradise Island Bay Rum   1140.425000

# %%
profit_by_brand=iowa.groupby(['description']) [['profit_gallon']].mean().reset_index()
profit_by_brand=profit_by_brand.sort_values(['profit_gallon'], ascending=[0])
profit_by_brand.head(10)
##The sales and profit both have brands with higher return, but they do not seem consistent between the two. 
##I find it interesting that several of the mini bottles correlate to higher profit.
# Out:
#                                           description  profit_gallon
# 1125  Johnnie Walker Private Collection 2015 Fruit HA    1062.500000
# 404                                  Caol Ila 30YR HA     875.000000
# 561            Cragganmore Distillers Edition 25YR HA     700.000000
# 307                         Bombay Sapphire Gin Minis     615.384615
# 1281                                Maker's Mark Mini     604.615385
# 959                   Hennessy 250 Collector Blend HA     576.923077
# 1606                               Pittyvaich 25YR HA     560.400000
# 1372                                 Mortlach 18YR HA     420.000000
# 1648                                Redbreast 21yr HA     377.118644
# 1274                            Macallan Rare Cask HA     375.950000

# %% [markdown]
# ### 5.8 The tax board wants to design a tax or taxes that affect larger stores more than smaller "mom and pop" stores.
#
# Based on your investigations into the data, come up with a way you could design a tax that achieves this goal **without explicitly taxing stores based on size or county critera.** The liqour board does not want to obviously punish larger stores or speific counties for fear of backlash, but is willing to tax hard alcohol more than beer, for example.
#
# Feel free to do more EDA if it helps.
#
# Your report should describe whether such a tax is possible or not, and the specifics of what the tax will target/do.

# %%
#psales by category and county

county_sales=iowa.groupby(['county_num', 'broad_category'])['sales'].sum().reset_index()
county_sales=county_sales.sort_values(['sales'], ascending=[0])
county_sales.head(10)

##Whiskey followed by vodka have the highest sales in Des Moines
# Out:
#      county_num broad_category       sales
# 687        77.0              1  2121149.97
# 689        77.0              3  2102624.85
# 694        77.0              8  1280687.84
# 692        77.0              6   894933.67
# 505        57.0              1   870486.71
# 507        57.0              3   812654.97
# 734        82.0              1   683266.51
# 460        52.0              1   635124.81
# 736        82.0              3   623895.81
# 512        57.0              8   553153.37

# %%
#profit by category and county

county_profit=iowa.groupby(['county_num', 'broad_category'])['profit'].sum().reset_index()
county_profit=county_profit.sort_values(['profit'], ascending=[0])
county_profit.head(10)

##Whiskey followed by vodka have the highest profit in Des Moines.
# Out:
#      county_num broad_category     profit
# 687        77.0              1  709225.92
# 689        77.0              3  702747.23
# 694        77.0              8  427312.94
# 692        77.0              6  298652.09
# 505        57.0              1  291428.46
# 507        57.0              3  271404.75
# 734        82.0              1  228188.30
# 460        52.0              1  212234.10
# 736        82.0              3  208325.73
# 512        57.0              8  184580.14

# %%
#small profit 
county_sales=county_sales.sort_values(['sales'], ascending=[1])
county_sales.head()
# Out:
#      county_num broad_category  sales
# 332        38.0              0  22.31
# 341        39.0              0  27.00
# 226        26.0              0  29.04
# 9           2.0              0  40.50
# 63          7.0              9  49.50

# %% [markdown]
# From looking at the initial outlier investigation, you can see that there is a pretty large concentration of small mom and pops dictating the mean and then a lot of stores that are much biger. Looking at the data in section 5 we can see that tequila is linked to high sales and profit margins. We also discovered that most of the bigger stores are in Des Moines, so I isolate their county number to futher investigate liquor type sold there (vodka and liquor). I might suggest placing a tax on vodka, but this seems too specific. Perhaps an overall tax on hard liquor would be the most feasible solution.

# %% [markdown]
# ## 6. Case 2 = Market research for new store locations
#
# A liquor store owner in Iowa is looking to open a store in a new location and has hired you as a consultant to investigate the market data for potential new locations. The business owner is interested in what you can discover from the data that will help him evaluate a good location for a new storefront.
#
# ---
#
# ### 6.1 Create columns for Q1 2015 sales and Q1 2016 sales.
#
# The owner is not just interested in what locations are currently selling well, but also which areas are showing the most promising sales growth from 2015 to 2016.
#
# For yearly changes we will focus on the changes from Q1 2015 to Q1 2016 specifically (avoiding effects of season changes).
#
# Note: Q1 is months: January, February, and March.

# %%
##We already did this in number 4 by setting the time with pandas, separating each quarter, and merging them into the 'quarter_sales' data set.

# %%
quarter_sales.describe()
# Out:
#            level_0        index        store  quarter1_sales15  \
# count  1170.000000  1170.000000  1170.000000       1170.000000
# mean    625.295726   625.295726  4154.544444       5083.214632
# std     362.581104   362.581104   801.647012      11977.314109
# min       0.000000     0.000000  2106.000000         11.210000
# 25%     313.250000   313.250000  3789.250000        892.392500
# 50%     626.500000   626.500000  4371.500000       1904.120000
# 75%     935.750000   935.750000  4732.750000       4725.580000
# max    1260.000000  1260.000000  9002.000000     207012.080000
#
#        quarter2_sales15  quarter3_sales15  quarter4_sales15  quarter1_sales16  \
# count       1170.000000       1170.000000       1170.000000       1170.000000
# mean        6012.085094       5549.277239       6769.675607       5194.993769
# std        14703.851284      12158.624350      15879.804133      12212.845149
# min           32.400000         82.260000         53.270000         30.600000
# 25%          965.582500       1008.585000       1035.787500        974.795000
# 50%         2070.110000       2099.940000       2316.485000       1908.280000
# 75%         5377.325000       5171.150000       6179.655000       4748.410000
# max       277634.390000     212606.590000     267137.840000     219551.790000
#
#           sales_2015
# count    1170.000000
# mean    23414.252573
# std     53828.656810
# min       450.010000
# 25%      3951.765000
# 50%      8573.455000
# 75%     22351.900000
# max    964390.900000

# %% [markdown]
# ### 6.2 Decide on a metric for performance that combines Q1 2016 sales as well as growth in sales from Q1 2015.
#
# Again, the owner wants to know that his store will be in a good position to sell a large amount of liquor now, but also have his store be more likely to grow and sell even more going forward.
#
# In particular, he is worried about opening a store in an area that is showing a decline in liquor sales between Q1 2015 and Q1 2016.

# %% [markdown]
# ### 6.3 Recommend a location based on your metric.
#
# The owner asks you to make a recommendation for a new store location. Explain why you recommended this area.

# %% [markdown]
# ### 6.4 Recommend a location based also on a restricted inventory type.
#
# Your employer has now decided he wants his store to focus on one type of liquor only. He askes you:
#
# 1. What would be the best type of liquor to sell to maximize profit?
# 2. Should the recommended location change if he is only selling one type of liquor?
